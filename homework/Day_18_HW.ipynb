# %%
# 載入需要的...
import matplotlib.pyplot as plt
import numpy as np

#畫出完整的 cos 圖形
x = np.arange(0,360)
y = np.cos(x * np.pi / 180)

plt.plot(x,y)

# 如果要存成圖形檔:
# 把 pyplot.show() 換成下面這行:
plt.savefig("cos函數.png",dpi=300,format="png")

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

ang = np.arctan2(Y/X)

plt.scatter(X, Y, c = ang)

plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-39141e7fed6d> in <module>
#       3 Y = np.random.normal(0,1,n)
#       4
# ----> 5 ang = np.arctan2(Y/X)
#       6
#       7 plt.scatter(X, Y, c = ang)
#
# ValueError: invalid number of arguments
