# %%
import numpy as np
V1 = 20000
V0 = 20
GdB = 20 * np.log10(V1/V0)
GdB
# Out:
# 60.0

# %%
V50 = V0 * np.power(10,(50/20))
V30 = V0 * np.power(10,(30/20))
x = V30/V50
x
# Out:
# 0.09999999999999999
